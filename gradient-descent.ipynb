# %% [markdown]
# #### Name: Sankalp Indish
# #### Roll No: BEB75
# #### Batch: B4
# #### Title:  Implement Gradient Descent Algorithm to find the local minima of a function. For example, find the local minima of the function y=(x+3)² starting from the point x=2.

# %%
import matplotlib.pyplot as plt

# Define the function and its derivative
def f(x):
    return (x + 3) ** 2

def f_derivative(x):
    return 2 * (x + 3)

# Gradient Descent parameters
x = 2                  # Starting point
learning_rate = 0.1    # Step size
epochs = 20            # Number of iterations

# For plotting
x_vals = [x]
y_vals = [f(x)]

# Gradient Descent loop
for i in range(epochs):
    grad = f_derivative(x)
    x = x - learning_rate * grad
    x_vals.append(x)
    y_vals.append(f(x))
    print(f"Step {i+1}: x = {x:.4f}, f(x) = {f(x):.4f}")

# Final result
print(f"\nLocal minimum occurs at x = {x:.4f}")
print(f"Minimum value of function = {f(x):.4f}")

# Plotting the function and the descent path
x_range = [i for i in range(-6, 3)]
y_range = [f(i) for i in x_range]
plt.plot(x_range, y_range, label="f(x) = (x + 3)^2", color='blue')
plt.scatter(x_vals, y_vals, color='red', label="Gradient Descent Path")
plt.plot(x_vals, y_vals, '--', color='red')
plt.title("Gradient Descent to Find Local Minima")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Step 1: x = 1.0000, f(x) = 16.0000
# Step 2: x = 0.2000, f(x) = 10.2400
# Step 3: x = -0.4400, f(x) = 6.5536
# Step 4: x = -0.9520, f(x) = 4.1943
# Step 5: x = -1.3616, f(x) = 2.6844
# Step 6: x = -1.6893, f(x) = 1.7180
# Step 7: x = -1.9514, f(x) = 1.0995
# Step 8: x = -2.1611, f(x) = 0.7037
# Step 9: x = -2.3289, f(x) = 0.4504
# Step 10: x = -2.4631, f(x) = 0.2882
# Step 11: x = -2.5705, f(x) = 0.1845
# Step 12: x = -2.6564, f(x) = 0.1181
# Step 13: x = -2.7251, f(x) = 0.0756
# Step 14: x = -2.7801, f(x) = 0.0484
# Step 15: x = -2.8241, f(x) = 0.0309
# Step 16: x = -2.8593, f(x) = 0.0198
# Step 17: x = -2.8874, f(x) = 0.0127
# Step 18: x = -2.9099, f(x) = 0.0081
# Step 19: x = -2.9279, f(x) = 0.0052
# Step 20: x = -2.9424, f(x) = 0.0033
#
# Local minimum occurs at x = -2.9424
# Minimum value of function = 0.0033

# %% [markdown]
# ### **Conclusion**
#
# The implemented gradient descent algorithm successfully minimizes the function $f(x) = (x + 3)^2$ starting from $x = 2$. Through iterative updates using the function's derivative, the algorithm converges toward the local minimum at $x = -3$. The step-by-step decrease in function value and the plotted descent path visually confirm the effectiveness of gradient descent in finding local minima for convex functions.
